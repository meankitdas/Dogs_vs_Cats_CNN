# %%
from keras.applications.xception import Xception
import numpy as np

# %%
from keras.preprocessing import image
from keras.applications.xception import preprocess_input, decode_predictions

# %%
model = Xception(weights='imagenet')
# Out:
# 2023-12-10 00:43:41.524009: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2023-12-10 00:43:41.524035: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-12-10 00:43:41.524039: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-12-10 00:43:41.524072: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-12-10 00:43:41.524084: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
img = 'dog7.png'
img = image.load_img(img, target_size=(299,299))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=299x299>

# %%
x = image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
# [[[
# [[[[
x
# Out:
# array([[[[-0.1607843 , -0.1372549 , -0.2862745 ],
#          [-0.20784312, -0.18431371, -0.3333333 ],
#          [-0.27843136, -0.27058822, -0.41960782],
#          ...,
#          [ 0.85882354,  0.9137255 ,  0.9372549 ],
#          [ 0.8666667 ,  0.90588236,  0.9372549 ],
#          [ 0.8901961 ,  0.9372549 ,  0.9607843 ]],
#
#         [[-0.15294117, -0.12941176, -0.27843136],
#          [-0.21568626, -0.19999999, -0.3490196 ],
#          [-0.2862745 , -0.27058822, -0.42745095],
#          ...,
#          [ 0.85882354,  0.92156863,  0.94509804],
#          [ 0.85882354,  0.92941177,  0.9529412 ],
#          [ 0.88235295,  0.9607843 ,  0.96862745]],
#
#         [[-0.15294117, -0.14509803, -0.2862745 ],
#          [-0.2235294 , -0.19999999, -0.3333333 ],
#          [-0.29411763, -0.27058822, -0.41960782],
#          ...,
#          [ 0.8509804 ,  0.92156863,  0.94509804],
#          [ 0.8509804 ,  0.92156863,  0.94509804],
#          [ 0.8666667 ,  0.94509804,  0.96862745]],
#
#         ...,
#
#         [[-0.09019607, -0.10588235, -0.1372549 ],
#          [-0.16862744, -0.19999999, -0.23137254],
#          [-0.19999999, -0.23921567, -0.27058822],
#          ...,
#          [-0.7176471 , -0.69411767, -0.88235295],
#          [-0.7176471 , -0.69411767, -0.8901961 ],
#          [-0.7411765 , -0.7176471 , -0.90588236]],
#
#         [[-0.10588235, -0.14509803, -0.18431371],
#          [-0.1607843 , -0.20784312, -0.23921567],
#          [-0.16862744, -0.20784312, -0.24705881],
#          ...,
#          [-0.7254902 , -0.69411767, -0.8901961 ],
#          [-0.7254902 , -0.69411767, -0.8901961 ],
#          [-0.7490196 , -0.7019608 , -0.9137255 ]],
#
#         [[-0.12156862, -0.1607843 , -0.19215685],
#          [-0.16862744, -0.19999999, -0.24705881],
#          [-0.17647058, -0.20784312, -0.25490195],
#          ...,
#          [-0.7019608 , -0.6862745 , -0.8745098 ],
#          [-0.70980394, -0.6862745 , -0.8666667 ],
#          [-0.73333335, -0.7176471 , -0.8980392 ]]]], dtype=float32)

# %%
pred = model.predict(x)
# Out:
# 2023-12-10 00:43:42.859397: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 1s 598ms/step

# %%
decode_predictions(pred, top=3)[0]
# Out:
# [('n02093428', 'American_Staffordshire_terrier', 0.33535457),
#  ('n02108422', 'bull_mastiff', 0.29745254),
#  ('n02093256', 'Staffordshire_bullterrier', 0.066385254)]
